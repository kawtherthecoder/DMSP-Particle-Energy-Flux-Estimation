# %%
#This file finds the conjunctions between SSUSI and SSJ observations across the time frame studied.

import datetime
from geospacepy import special_datetime, satplottools
from geospacepy.special_datetime import (datetimearr2jd,
                                        datetime2jd,
                                        jd2datetime)
import os, glob, string, numpy as np
import pdb
import scipy
import matplotlib as mpl
import matplotlib.pyplot as pp
from matplotlib.gridspec import GridSpec
import sys
import time
import h5py
from numpy import (sin,cos,tan,arcsin,arccos,arctan2)
from copy import copy, deepcopy
from ssj import SSJDay # ssj2 contains updated function to read CDF files
from ssusi3 import SDRPass # ssusi3 contains new SSUSI-based features
from sklearn.neighbors import NearestNeighbors


class SSUSIandSSJConjunctions(object):

    @staticmethod
    def get_conjunction_data(ssusi_pass_obs,ssj_pass_obs, obs_to_interpolate = ['LBHL', 'LBHS','solar_irr_mask','aurora_mask'], k = 10, tol = 1.5):
        """
        Performs K nearest neighbors distance weighted average and returns dictionary of SSUSI-SSJ conjunction data for a given SSUSI and SSJ data


        Parameters 
        ----------
        ssusi_pass_obs : dict object with elements
            ['jds'] : np.ndarray (n_obs x 1)
                Array of observation times (in Julian Date)
            ['lats'] : np.ndarray (n_obs x 1)
                Magnetic latitude (degrees) of observations in Apex coordinates of reference height 110 km 
            ['lons'] : np.ndarray (n_obs x 1)
                Magnetic local time of observations (expressed in degrees ) of observations in Apex coordinates 

            Observations of the form 
            ['LBHL']  : np.ndarray (n_obs x 1)
            ['LBHS']  : np.ndarray (n_obs x 1)
            ['Lyman Alpha']  : np.ndarray (n_obs x 1)
            ['OI 130.4']  : np.ndarray (n_obs x 1)
            ['OI 135.6']  : np.ndarray (n_obs x 1)

        ssj_pass_obs : dict object 
            Same dict as output from SSJDay get_ingest_data() 
        obs_to_interpolate : list of str 
            Needs to be subset of ['Lyman Alpha','OI 130.4', 'OI 135.6', 'LBHS', 'LBHL']
            Defaults to ['LBHL', 'LBHS']
        k : int 
            Neighbor of SSUSI pixels to include in distance weighted averaging
        tol : float 
            Tolerated distance (in degrees) from SSUSI obs to SSJ obs to be considered in a given conjunction statistic

        Returns
        -------
        conjunction_dict : dict object 
            Same elements as ssj_pass_obs with interpolated SSUSI obs values on the SSJ track
            eg. ['LBHL_interped']
        """
        conjunction_dict = deepcopy(ssj_pass_obs)

        #iterate across observations to interp and put them in a dictionary 
        for obs_name in obs_to_interpolate:
            conjunction_dict[obs_name + '_interped'] = SSUSIandSSJConjunctions.dmsp_map_interpolate_NN_smooth_great_circle(ssj_pass_obs['lats'], ssj_pass_obs['lons'], \
                                                                            ssusi_pass_obs['lats'], ssusi_pass_obs['lons'], ssusi_pass_obs[obs_name], \
                                                                            k = k, tol = tol)
        return conjunction_dict

    @staticmethod
    def write_to_h5(hd_dir, datadict, hemi, dmsp, dt):
        """
        Saves the conjunction dictionary as a h5 file 
        """
        file_dir = os.path.join(hd_dir,'SSUSI_SSJ_conjunctions_{}{}{}.hdf5'.format(hemi,dmsp,dt.strftime('%Y%m%d_%H:%M')))

        # KAWTHER DEBUG HERE
        # if file_dir == '/Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/SSUSI_SSJ_conjunctions_N1620140221_00:06.hdf5':
        #     print('\n\n\n Printing data dictionary for sample HDF5 file\n\n\n')
        #     print(datadict)

        #write data dictionary to h5 file 
        h5f = h5py.File(file_dir,'w')
        for key in datadict:
            h5f.create_dataset(key,data = datadict[key])
        h5f.close()
        return
    
    @staticmethod
    def dmsp_map_interpolate_NN_smooth_great_circle(lat_dmsp, lon_dmsp, lat_map, lon_map, Obs_map, k = 5, tol = 1.5):
        """
        Wrapper for Sklearn's nearestneighbor with haversine distance 
        """
        tol = np.deg2rad(tol)
        #reshape to N by 2 array where each row is (lat, lon)
        dmsp_points = np.deg2rad(np.hstack((lat_dmsp.flatten().reshape(-1,1),lon_dmsp.flatten().reshape(-1,1))))
        map_points = np.deg2rad(np.hstack((lat_map.flatten().reshape(-1,1), lon_map.flatten().reshape(-1,1))))
        N_points = dmsp_points.shape[0]
        obs_val = Obs_map.flatten()

        model = NearestNeighbors(n_neighbors = k, radius = tol, metric = 'haversine')

        model.fit(map_points)
        neighbors = model.kneighbors(dmsp_points, return_distance = True)
        
        #indices
        obs_interp = np.empty(N_points)
        for i in range(N_points):
            distances = neighbors[0][i]
            inds = neighbors[1][i]
            
            weights = distances/np.nansum(distances)
            obs_interp[i] = np.nansum( obs_val[inds] * weights)
            
            
        return obs_interp


#Feel free to change this to whatever timeframe you need 
dmsp_arr = [17,18] #satellites to run for 
year = 2014
day_arr = [17,18,19,20,21,22,23] #days of month to run for  
doy_arr = [48,49,50,51,52,53,54]

# dmsp_arr = [18] #satellites to run for 
# year = 2014
# day_arr = [20] #days of month to run for  
# doy_arr = [51]

hemis = ['N','S']
radiances_to_use = ['LBHL','LBHS','Lyman Alpha']
#make sure to change this 
# ssusi_dir = os.path.join('/home/matsuo/amgeo_dev/LBH_to_eflux/LBH_to_eflux/','SSUSI_SDR_Observations')
# ssj_dir = os.path.join('/home/matsuo/amgeo_dev/LBH_to_eflux/LBH_to_eflux/','SSJ_Observations')
ssusi_dir = os.path.join('/Volumes/Sandisk500/AMGeO/DMSP LEO/SSUSI/','SSUSISDR')
ssj_dir = os.path.join('/Volumes/Sandisk500/AMGeO/DMSP LEO/','SSJ')

#place you would like to save the conjunction files 
conjunction_dir = '/Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/'
if not os.path.exists(conjunction_dir):
    os.mkdir(conjunction_dir)

passnumber = 0
for doy in doy_arr:
    ssj_day_dir = ssj_dir + '/{}{}'.format(year,doy)
    ssusi_day_dir = ssusi_dir +  '/{}{}'.format(year,doy)
    
    for dmsp in dmsp_arr:

        if len(glob.glob(os.path.join(ssj_day_dir,'dmsp-f%d_ssj_*.cdf' % (dmsp)))) == 0:
            print('\n\n\n\nFILE NOT FOUND:')
            print(os.path.join(ssj_day_dir,'dmsp-f%d_ssj_*.cdf' % (dmsp)))
            continue

        #read the SSJ obs file
        day_ssj_file =  glob.glob(os.path.join(ssj_day_dir,'dmsp-f%d_ssj_*.cdf' % (dmsp)))[0]
        ssj_obs = SSJDay(dmsp,'N',day_ssj_file, read_spec = True)
        
        #get all the ssusi files
        ssusi_files = glob.glob(os.path.join(ssusi_day_dir, 'dmspf%d_ssusi_*' % (dmsp)))
        ssusi_files = np.sort(ssusi_files) 
        
        print('SSUSI file:',os.path.join(ssusi_day_dir, 'dmspf%d_ssusi_*' % (dmsp)))

        #iterate across the ssusi files
        for ssusi_file in ssusi_files:
            #convert file to byte literal
            ssusi_file = bytes(ssusi_file.encode())

            #get the observations for each file
            ssusi_obs_LBHL = SDRPass(ssusi_file, dmsp, 'N','LBHL')
            ssusi_obs_LBHS = SDRPass(ssusi_file, dmsp, 'N','LBHS')
            ssusi_obs_LYMAN = SDRPass(ssusi_file,dmsp, 'N','Lyman Alpha')

            #start and end times of this pass
            startdt = jd2datetime(np.nanmin(ssusi_obs_LBHL['jds']))
            enddt = jd2datetime(np.nanmax(ssusi_obs_LBHL['jds']))
            
            print('pass start time:',startdt)

            for hemi in hemis:
                try:
                    ssusi_lats,ssusi_lons,LBHL,LBHL_var,jds,solar_irr_mask,aurora_mask,radiance_fit = ssusi_obs_LBHL.get_ingest_data(hemisphere = hemi)
                    ssusi_lats,ssusi_lons,LYMAN,LYMAN_var,jds,solar_irr_mask,aurora_mask,radiance_fit = ssusi_obs_LYMAN.get_ingest_data(hemisphere = hemi) # kawther fixed typo
                    ssusi_lats,ssusi_lons,LBHS,LBHS_var,jds,solar_irr_mask,aurora_mask,radiance_fit = ssusi_obs_LBHS.get_ingest_data(hemisphere = hemi)

                    ssusi_pass_obs = {}
                    ssusi_pass_obs['lats'], ssusi_pass_obs['lons'], ssusi_pass_obs['jds']= ssusi_lats, ssusi_lons, jds
                    ssusi_pass_obs['LBHL'], ssusi_pass_obs['LBHL_var'] = LBHL, LBHL_var
                    ssusi_pass_obs['LBHS'], ssusi_pass_obs['LBHS_var'] = LBHS, LBHS_var
                    ssusi_pass_obs['LYMAN'], ssusi_pass_obs['LYMAN_var'] = LYMAN, LYMAN_var
                    ssusi_pass_obs['solar_irr_mask'], ssusi_pass_obs['aurora_mask'] = solar_irr_mask, aurora_mask

                    #get the relevant SSJ data for this pass 
                    ssj_pass_obs = ssj_obs.get_ingest_data(startdt = startdt, enddt = enddt, hemisphere = hemi)

                    # if ssusi obs overlap to next day, read next day ssj data and append to ssj_pass_obs dict
                    if enddt > np.nanmax(ssj_obs['epoch']):

                        ssj_next_day_dir = ssj_dir + '/{}{}'.format(year,doy+1)
                        next_day_ssj_file =  glob.glob(os.path.join(ssj_next_day_dir,'dmsp-f%d_ssj_*.cdf' % (dmsp)))[0]
                        ssj_obs_next_day = SSJDay(dmsp,'N',next_day_ssj_file, read_spec = True)
                        ssj_pass_obs_next_day = ssj_obs_next_day.get_ingest_data(startdt = startdt, enddt = enddt, hemisphere = hemi)

                        #append to ssj_pass _obs
                        for key in ssj_pass_obs:
                            ssj_pass_obs[key] =  np.append(ssj_pass_obs[key], ssj_pass_obs_next_day[key])                

                    #get times for the ssusi pass
                    pass_startdt = jd2datetime(np.nanmin(ssj_pass_obs['jds']))
                    pass_enddt = jd2datetime(np.nanmax(ssj_pass_obs['jds']))
                    pass_center_dt = pass_startdt + (pass_enddt - pass_startdt)/2
                    print(pass_center_dt)

                    del ssj_pass_obs['epoch']

                    #get the conjunctions between SSUSI and SSJ 
                    conjunctions = SSUSIandSSJConjunctions.get_conjunction_data(ssusi_pass_obs, ssj_pass_obs, obs_to_interpolate = ['LBHL','LBHS','LYMAN','solar_irr_mask','aurora_mask'], k = 10, tol = 1)
                    conjunctions['pass_num'] = np.ones_like(conjunctions['jds']) * passnumber
                    conjunctions['sat_no'] = np.ones_like(conjunctions['jds']) * dmsp
                    if hemi == 'N':
                        conjunctions['hemi'] = np.ones_like(conjunctions['jds'])
                    else:
                        conjunctions['hemi'] = np.ones_like(conjunctions['jds']) * -1

                    #save to h5 file
                    SSUSIandSSJConjunctions.write_to_h5(conjunction_dir, conjunctions, hemi, dmsp, pass_center_dt)

                    print('H5 file written to',conjunction_dir)
                    passnumber+=1
                except Exception as e:
                    print(e,'~ Invalid conjunctions')
                else:
                    print("Conjunctions data saved successfully!")
print('Conjunction analysis complete!')
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.10/site-packages/spacepy/time.py:2367: UserWarning: Leapseconds may be out of date. Use spacepy.toolbox.update(leapsecs=True)
#   warnings.warn('Leapseconds may be out of date.'
# SSUSI file: /Volumes/Sandisk500/AMGeO/DMSP LEO/SSUSI/SSUSISDR/201448/dmspf17_ssusi_*
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# pass start time: 2014-02-17 01:04:53.745084
# 2014-02-17 01:16:37.500007
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-17 02:06:07.999989
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# pass start time: 2014-02-17 02:46:51.197720
# 2014-02-17 02:58:46.499997
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-17 03:49:20.999993
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# pass start time: 2014-02-17 04:28:45.600886
# 2014-02-17 04:41:25.000006
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-17 05:32:50.500008
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# pass start time: 2014-02-17 06:10:41.283104
# 2014-02-17 06:23:48.500017
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-17 07:16:40.999988
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# pass start time: 2014-02-17 07:52:36.873228
# 2014-02-17 08:06:10.499995
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-17 08:59:47.500008
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# pass start time: 2014-02-17 09:34:32.296143
# 2014-02-17 09:48:51.499991
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-17 10:41:54.500007
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# pass start time: 2014-02-17 11:16:29.628603
# 2014-02-17 11:31:22.000005
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-17 12:23:18.499999
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# pass start time: 2014-02-17 12:58:26.155273
# 2014-02-17 13:12:59.500003
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-17 14:04:10.500002
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# pass start time: 2014-02-17 14:40:19.967374
# 2014-02-17 14:54:15.499998
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-17 15:44:59.000006
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# pass start time: 2014-02-17 16:22:17.279758
# 2014-02-17 16:35:26.999997
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-17 17:25:42.999992
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# pass start time: 2014-02-17 18:04:13.364548
# 2014-02-17 18:16:37.000004
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-17 18:56:44.500000
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# pass start time: 2014-02-17 22:22:35.616854
# 2014-02-17 23:08:49.499997
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-17 22:31:17.999999
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# pass start time: 2014-02-17 23:09:52.067935
# 2014-02-18 00:00:48.000002
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 00:10:04.500000
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# SSUSI file: /Volumes/Sandisk500/AMGeO/DMSP LEO/SSUSI/SSUSISDR/201448/dmspf18_ssusi_*
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# pass start time: 2014-02-17 00:27:03.901552
# 2014-02-17 01:18:00.999997
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-17 01:27:00.499988
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# pass start time: 2014-02-17 02:08:58.774319
# 2014-02-17 02:59:56.000002
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-17 03:09:33.000010
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# pass start time: 2014-02-17 03:50:57.768045
# 2014-02-17 04:02:39.499987
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-17 04:52:41.499998
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# pass start time: 2014-02-17 05:32:50.021836
# 2014-02-17 05:45:09.999999
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-17 06:36:04.000010
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# pass start time: 2014-02-17 07:14:47.853751
# 2014-02-17 07:27:43.999993
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-17 08:19:49.499999
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# pass start time: 2014-02-17 08:56:44.745497
# 2014-02-17 09:10:08.000001
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-17 10:03:31.500006
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# pass start time: 2014-02-17 10:39:02.311281
# 2014-02-17 10:52:40.500003
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-17 11:46:11.000010
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# pass start time: 2014-02-17 12:20:57.207826
# 2014-02-17 12:35:28.500002
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-17 13:27:59.999987
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# pass start time: 2014-02-17 14:02:55.019382
# 2014-02-17 14:17:37.499991
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-17 15:09:09.999994
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# pass start time: 2014-02-17 15:44:50.676695
# 2014-02-17 15:59:02.499996
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-17 16:50:00.499986
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# Setting Apex epoch for 20140217 to 2014.131506849315
# pass start time: 2014-02-17 17:26:44.873425
# 2014-02-17 17:40:19.500006
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-17 18:30:51.999993
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# SSUSI file: /Volumes/Sandisk500/AMGeO/DMSP LEO/SSUSI/SSUSISDR/201449/dmspf17_ssusi_*
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 00:51:47.024910
# 2014-02-18 01:03:30.499992
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 01:52:51.499984
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 02:33:43.429553
# 2014-02-18 02:45:32.999995
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 03:36:02.999996
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 04:15:39.679058
# 2014-02-18 04:28:12.999997
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 05:19:29.500007
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 05:57:32.789654
# 2014-02-18 06:10:38
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 07:03:20.000008
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 07:39:30.779000
# 2014-02-18 07:52:59.000003
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 08:46:35.000001
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 09:21:28.551772
# 2014-02-18 09:35:37.500014
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 10:28:48.000008
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 11:03:23.440511
# 2014-02-18 11:18:13.499996
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 12:10:16.999993
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 12:45:17.107934
# 2014-02-18 12:59:57.500000
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 13:51:12.499998
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 14:27:15.514538
# 2014-02-18 14:41:13.500014
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 15:32:00.000006
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 16:09:13.367333
# 2014-02-18 16:22:26.000009
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 17:12:45.999983
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 17:51:08.825854
# 2014-02-18 18:03:35.999995
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 18:53:19.500007
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 19:33:02.969436
# 2014-02-18 20:24:11.500006
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 20:33:54.500002
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 21:14:59.978019
# 2014-02-18 22:05:55.499989
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 22:15:02.000003
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 22:56:55.814169
# 2014-02-18 23:47:51.500009
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 23:56:53.499985
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 23:03:27.275131
# 2014-02-18 23:11:42.500005
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 23:50:17.500001
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# SSUSI file: /Volumes/Sandisk500/AMGeO/DMSP LEO/SSUSI/SSUSISDR/201449/dmspf18_ssusi_*
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 01:45:59.307007
# 2014-02-18 01:55:41.000010
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# No observations for this time or hemisphere
# index 0 is out of bounds for axis 0 with size 0 ~ Invalid conjunctions
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 01:56:36.211620
# 2014-02-18 02:47:34.000003
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 02:57:05.500001
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 03:38:32.115481
# 2014-02-18 03:50:15.999996
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 04:40:11.000005
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 05:20:26.098694
# 2014-02-18 05:32:43.500005
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 06:23:32.000006
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 07:02:25.136516
# 2014-02-18 07:15:19.500008
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 08:07:14.499990
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 08:44:42.507209
# 2014-02-18 08:57:44.000014
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 09:51:01.499991
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 10:26:35.145790
# 2014-02-18 10:40:14.500006
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 11:33:48.500014
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 12:08:33.102467
# 2014-02-18 12:23:02.000007
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 13:15:42.499984
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 13:50:29.383434
# 2014-02-18 14:05:17.999999
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 14:56:57.000007
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 15:32:27.184007
# 2014-02-18 15:46:46.499986
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 16:37:47.999996
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 17:14:22.066953
# 2014-02-18 17:28:03.499995
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 18:18:39.000006
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 18:56:19.535441
# 2014-02-18 19:09:18.500015
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 19:59:22.999993
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 20:38:14.175701
# 2014-02-18 21:29:49.999987
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 21:39:55.499982
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 22:20:08.522058
# 2014-02-18 22:31:38.999986
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-18 23:20:47.500006
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# Setting Apex epoch for 20140218 to 2014.1342465753426
# pass start time: 2014-02-18 22:20:08.509786
# 2014-02-18 23:11:06.000002
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# No observations for this time or hemisphere
# index 0 is out of bounds for axis 0 with size 0 ~ Invalid conjunctions
# SSUSI file: /Volumes/Sandisk500/AMGeO/DMSP LEO/SSUSI/SSUSISDR/201450/dmspf17_ssusi_*
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 00:38:53.266403
# 2014-02-19 01:29:49.500017
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 01:39:35.499997
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 02:20:47.493750
# 2014-02-19 02:32:27.500011
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 03:22:44.999999
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 04:02:41.733328
# 2014-02-19 04:15:00.999988
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 05:06:09.000003
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 05:44:38.756033
# 2014-02-19 05:57:27.500002
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 06:49:57.999993
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 07:26:33.195127
# 2014-02-19 07:39:48.000009
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 08:33:21.500000
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 09:08:31.854637
# 2014-02-19 09:22:22.999998
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 10:15:41.500009
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 10:50:04.910946
# 2014-02-19 11:05:03.499997
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 11:57:15.499987
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 12:32:00.528589
# 2014-02-19 12:46:54.000006
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 13:38:14.000016
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 14:13:56.774996
# 2014-02-19 14:28:11.499992
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 15:19:01.000008
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 15:55:55.049475
# 2014-02-19 16:09:24.500003
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 16:59:47.999998
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 17:37:49.942398
# 2014-02-19 17:50:34.999986
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 18:40:23.500011
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 19:19:45.867906
# 2014-02-19 20:11:04.499990
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 20:20:56
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 21:01:40.860406
# 2014-02-19 21:52:36.499998
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 22:01:57.999991
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 22:43:36.287868
# 2014-02-19 23:34:32
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# No observations for this time or hemisphere
# index 0 is out of bounds for axis 0 with size 0 ~ Invalid conjunctions
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 22:50:31.156468
# 2014-02-19 22:58:40.000004
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 23:37:04.499997
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# SSUSI file: /Volumes/Sandisk500/AMGeO/DMSP LEO/SSUSI/SSUSISDR/201450/dmspf18_ssusi_*
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 00:02:29.458252
# 2014-02-19 00:53:26.999986
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 01:02:18.500000
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 01:44:22.755127
# 2014-02-19 02:35:20.000001
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 02:44:38.499989
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 03:26:20.466664
# 2014-02-19 03:37:59.499988
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 04:27:41.500007
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 05:08:14.882382
# 2014-02-19 05:20:17.000010
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 06:11:00.499998
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 06:50:13.202043
# 2014-02-19 07:02:55.500000
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 07:54:39.500001
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 08:32:07.029955
# 2014-02-19 08:45:20.500003
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 09:38:30.500000
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 10:14:01.488402
# 2014-02-19 10:27:48.499989
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 11:21:25.000004
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 11:55:59.890620
# 2014-02-19 12:10:35.999990
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 13:03:24.500004
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 13:38:20.208914
# 2014-02-19 13:52:59.000004
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 14:44:43.500002
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 15:20:14.790876
# 2014-02-19 15:34:30.500015
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 16:25:36.000003
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 17:02:08.737678
# 2014-02-19 17:15:48.000001
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 18:06:26.999993
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 18:44:03.815754
# 2014-02-19 18:57:02.500004
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 19:47:12.499992
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 20:26:02.730584
# 2014-02-19 20:38:15.999992
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 21:27:45.500019
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 22:07:58.415859
# 2014-02-19 22:58:56.499996
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-19 23:08:32.999987
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# Setting Apex epoch for 20140219 to 2014.13698630137
# pass start time: 2014-02-19 23:49:53.134211
# 2014-02-20 00:40:51.000003
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# No observations for this time or hemisphere
# index 0 is out of bounds for axis 0 with size 0 ~ Invalid conjunctions
# SSUSI file: /Volumes/Sandisk500/AMGeO/DMSP LEO/SSUSI/SSUSISDR/201451/dmspf17_ssusi_*
# Setting Apex epoch for 20140220 to 2014.1397260273973
# Setting Apex epoch for 20140220 to 2014.1397260273973
# Setting Apex epoch for 20140220 to 2014.1397260273973
# pass start time: 2014-02-20 00:25:33.831431
# 2014-02-20 01:16:29.500011
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-20 01:26:19.999986
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140220 to 2014.1397260273973
# Setting Apex epoch for 20140220 to 2014.1397260273973
# Setting Apex epoch for 20140220 to 2014.1397260273973
# pass start time: 2014-02-20 02:07:28.397420
# 2014-02-20 02:19:13.999990
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-20 03:09:27.500000
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140220 to 2014.1397260273973
# Setting Apex epoch for 20140220 to 2014.1397260273973
# Setting Apex epoch for 20140220 to 2014.1397260273973
# pass start time: 2014-02-20 03:49:24.808139
# 2014-02-20 04:01:48.999999
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-20 04:52:48.500000
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140220 to 2014.1397260273973
# Setting Apex epoch for 20140220 to 2014.1397260273973
# Setting Apex epoch for 20140220 to 2014.1397260273973
# pass start time: 2014-02-20 05:31:19.956222
# 2014-02-20 05:44:17.000005
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-20 06:36:35.500000
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140220 to 2014.1397260273973
# Setting Apex epoch for 20140220 to 2014.1397260273973
# Setting Apex epoch for 20140220 to 2014.1397260273973
# pass start time: 2014-02-20 07:13:17.781980
# 2014-02-20 07:26:37.500012
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-20 08:20:06.499988
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140220 to 2014.1397260273973
# Setting Apex epoch for 20140220 to 2014.1397260273973
# Setting Apex epoch for 20140220 to 2014.1397260273973
# pass start time: 2014-02-20 08:55:15.946341
# 2014-02-20 09:09:09.499997
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-20 10:02:33.999996
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140220 to 2014.1397260273973
# Setting Apex epoch for 20140220 to 2014.1397260273973
# Setting Apex epoch for 20140220 to 2014.1397260273973
# pass start time: 2014-02-20 10:37:09.692379
# 2014-02-20 10:51:52.500002
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-20 11:44:13.000007
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140220 to 2014.1397260273973
# Setting Apex epoch for 20140220 to 2014.1397260273973
# Setting Apex epoch for 20140220 to 2014.1397260273973
# pass start time: 2014-02-20 12:19:08.113306
# 2014-02-20 12:33:50.500010
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-20 13:25:15.499994
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140220 to 2014.1397260273973
# Setting Apex epoch for 20140220 to 2014.1397260273973
# Setting Apex epoch for 20140220 to 2014.1397260273973
# pass start time: 2014-02-20 14:01:01.807725
# 2014-02-20 14:15:09.499988
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-20 15:06:01.999988
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140220 to 2014.1397260273973
# Setting Apex epoch for 20140220 to 2014.1397260273973
# Setting Apex epoch for 20140220 to 2014.1397260273973
# pass start time: 2014-02-20 15:42:57.199258
# 2014-02-20 15:56:22.500019
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# ...
# Setting Apex epoch for 20140222 to 2014.145205479452
# pass start time: 2014-02-22 19:49:05.815068
# 2014-02-22 20:01:30.000008
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-22 20:51:13.999996
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140222 to 2014.145205479452
# Setting Apex epoch for 20140222 to 2014.145205479452
# Setting Apex epoch for 20140222 to 2014.145205479452
# pass start time: 2014-02-22 21:31:01.327261
# 2014-02-22 22:22:12.999998
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-22 22:31:51.999996
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140222 to 2014.145205479452
# Setting Apex epoch for 20140222 to 2014.145205479452
# Setting Apex epoch for 20140222 to 2014.145205479452
# pass start time: 2014-02-22 23:12:56.009484
# 2014-02-23 00:03:53.500001
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# No observations for this time or hemisphere
# index 0 is out of bounds for axis 0 with size 0 ~ Invalid conjunctions
# SSUSI file: /Volumes/Sandisk500/AMGeO/DMSP LEO/SSUSI/SSUSISDR/201454/dmspf17_ssusi_*
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 01:28:19.860612
# 2014-02-23 01:39:57.500018
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-23 02:29:35.499999
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 03:10:17.507051
# 2014-02-23 03:22:09.500010
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-23 04:12:51.500007
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 04:52:12.191165
# 2014-02-23 05:04:44.000002
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-23 05:56:26.999988
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 06:33:45.605831
# 2014-02-23 06:47:05.500003
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-23 07:40:14.500007
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 08:15:41.475776
# 2014-02-23 08:29:30.499986
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-23 09:23:05.499989
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 09:57:38.509465
# 2014-02-23 10:12:14.500006
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-23 11:05:01.500007
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 11:39:33.184083
# 2014-02-23 11:54:34.500016
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-23 12:46:17.000005
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 13:21:30.208760
# 2014-02-23 13:36:03.000002
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-23 14:27:06.500003
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 15:03:26.579125
# 2014-02-23 15:17:17.499985
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-23 16:07:54.500008
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 16:45:21.900894
# 2014-02-23 16:58:29.000004
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-23 17:48:37.000003
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 18:27:18.961579
# 2014-02-23 18:39:38.499994
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-23 19:29:06.999985
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 20:09:13.439015
# 2014-02-23 20:20:43.500008
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-23 21:09:51.500010
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 21:58:47.540955
# 2014-02-23 22:49:43.000001
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-23 22:51:13.499993
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 23:38:36.009982
# list index out of range ~ Invalid conjunctions
# No observations for this time or hemisphere
# index 0 is out of bounds for axis 0 with size 0 ~ Invalid conjunctions
# SSUSI file: /Volumes/Sandisk500/AMGeO/DMSP LEO/SSUSI/SSUSISDR/201454/dmspf18_ssusi_*
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 00:54:52.967293
# 2014-02-23 01:45:49.999997
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-23 01:54:58.500000
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 02:36:47.906927
# 2014-02-23 02:48:28.999986
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-23 03:37:44.499988
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 04:18:43.751405
# 2014-02-23 04:30:29.500001
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-23 05:20:56.500017
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 06:00:41.722485
# 2014-02-23 06:13:14.999993
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-23 07:04:24.000003
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 07:42:57.971841
# 2014-02-23 07:55:44.499991
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-23 08:48:16.500014
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 09:24:52.032140
# 2014-02-23 09:38:08.999996
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-23 10:31:42.999984
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 11:06:50.817540
# 2014-02-23 11:20:47.000009
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-23 12:14:06.999993
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 12:48:45.540921
# 2014-02-23 13:03:30.500011
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-23 13:55:43.499996
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 14:30:42.110279
# 2014-02-23 14:45:23.999984
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-23 15:36:46.000004
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 16:12:40.383993
# 2014-02-23 16:26:44.499995
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-23 17:17:35.999999
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 17:54:33.692657
# 2014-02-23 18:08:00.499989
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-23 18:58:26.000014
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 19:45:50.684242
# 2014-02-23 20:36:49.000002
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-23 20:39:03.499996
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 21:18:27.279731
# 2014-02-23 22:09:50.000005
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-23 22:19:39.500006
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 23:00:43.691589
# list index out of range ~ Invalid conjunctions
# list index out of range ~ Invalid conjunctions
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# Setting Apex epoch for 20140223 to 2014.1479452054793
# pass start time: 2014-02-23 23:08:21.368648
# 2014-02-23 23:15:52.999994
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# 2014-02-23 23:52:11.000009
# H5 file written to /Volumes/Sandisk500/AMGeO/DMSP LEO/conjunction_data/F1718-SSUSIv3/
# Conjunctions data saved successfully!
# Conjunction analysis complete!

# %%
# add try catch to avoid ^ error
